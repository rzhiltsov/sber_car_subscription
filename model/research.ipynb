# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import cross_val_score
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import OneHotEncoder

# %%
df = pd.merge(
        pd.read_csv('../data/ga_sessions.csv', dtype={'client_id': str}),
        pd.read_csv('../data/ga_hits.csv'),
        on='session_id'
    ).set_index('client_id')
df.head()
# Out:
#                                                       session_id  visit_date  \
# client_id
# 2108382700.1637753791  9055434745589932991.1637753792.1637753792  2021-11-24
# 2108382700.1637753791  9055434745589932991.1637753792.1637753792  2021-11-24
# 210838531.1636867288    905544597018549464.1636867290.1636867290  2021-11-14
# 2108385331.1640648523  9055446045651783499.1640648526.1640648526  2021-12-28
# 2108385331.1640648523  9055446045651783499.1640648526.1640648526  2021-12-28
#
#                       visit_time  visit_number            utm_source  \
# client_id
# 2108382700.1637753791   14:36:32             1  ZpYIoDJMcFzVoPFsHGJL
# 2108382700.1637753791   14:36:32             1  ZpYIoDJMcFzVoPFsHGJL
# 210838531.1636867288    08:21:30             1  MvfHsxITijuriZxsqZqt
# 2108385331.1640648523   02:42:06             1  ZpYIoDJMcFzVoPFsHGJL
# 2108385331.1640648523   02:42:06             1  ZpYIoDJMcFzVoPFsHGJL
#
#                       utm_medium          utm_campaign         utm_adcontent  \
# client_id
# 2108382700.1637753791     banner  LEoPHuyFvzoNfnzGgfcd  vCIpmpaGBnIQhyYNkXqp
# 2108382700.1637753791     banner  LEoPHuyFvzoNfnzGgfcd  vCIpmpaGBnIQhyYNkXqp
# 210838531.1636867288         cpm  FTjNLDyTrXaWYgZymFkV  xhoenQgDQsgfEPYNPwKO
# 2108385331.1640648523     banner  LEoPHuyFvzoNfnzGgfcd  vCIpmpaGBnIQhyYNkXqp
# 2108385331.1640648523     banner  LEoPHuyFvzoNfnzGgfcd  vCIpmpaGBnIQhyYNkXqp
#
#                                 utm_keyword device_category  ...    hit_date  \
# client_id                                                    ...
# 2108382700.1637753791  puhZPIYqKXeFPaUviSjo          mobile  ...  2021-11-24
# 2108382700.1637753791  puhZPIYqKXeFPaUviSjo          mobile  ...  2021-11-24
# 210838531.1636867288   IGUCNvHlhfHpROGclCit          mobile  ...  2021-11-14
# 2108385331.1640648523  puhZPIYqKXeFPaUviSjo          mobile  ...  2021-12-28
# 2108385331.1640648523  puhZPIYqKXeFPaUviSjo          mobile  ...  2021-12-28
#
#                        hit_time hit_number hit_type hit_referer  \
# client_id
# 2108382700.1637753791    3665.0          3    event         NaN
# 2108382700.1637753791   46592.0          4    event         NaN
# 210838531.1636867288      921.0          3    event         NaN
# 2108385331.1640648523   84155.0         10    event         NaN
# 2108385331.1640648523  102979.0         13    event         NaN
#
#                                                            hit_page_path  \
# client_id
# 2108382700.1637753791                             podpiska.sberauto.com/
# 2108382700.1637753791                             podpiska.sberauto.com/
# 210838531.1636867288                              podpiska.sberauto.com/
# 2108385331.1640648523  sberauto.com/cars?utm_source_initial=sbol&utm_...
# 2108385331.1640648523  sberauto.com/cars?utm_source_initial=sbol&utm_...
#
#                          event_category         event_action  \
# client_id
# 2108382700.1637753791     sub_page_view          sub_landing
# 2108382700.1637753791  sub_button_click  sub_view_cars_click
# 210838531.1636867288      sub_page_view          sub_landing
# 2108385331.1640648523       search_form   search_form_region
# 2108385331.1640648523       search_form   search_form_region
#
#                                 event_label  event_value
# client_id
# 2108382700.1637753791                   NaN          NaN
# 2108382700.1637753791  vodKSlUobUWTVlgsJqdI          NaN
# 210838531.1636867288                    NaN          NaN
# 2108385331.1640648523  KWTCzSIXzoqUWjfUQMgP          NaN
# 2108385331.1640648523  CBqnBQaKoQUyWJhLcxxN          NaN
#
# [5 rows x 27 columns]

# %% [markdown]
# # Data Cleaning

# %%
actions = {'sub_car_claim_click', 'sub_car_claim_submit_click', 'sub_open_dialog_click',
               'sub_custom_question_submit_click', 'sub_call_number_click', 'sub_callback_submit_click',
               'sub_submit_success', 'sub_car_request_submit_click'}
df = pd.concat([
    df.hit_number,
    df.filter(regex='^(utm|device|geo)_.+'),
    df.event_action.apply(lambda event_action: int(event_action in actions)).rename('target_action')
], axis=1)

print(df.shape)
df.head()
# Out:
# (15685219, 15)
#                        hit_number            utm_source utm_medium  \
# client_id
# 2108382700.1637753791           3  ZpYIoDJMcFzVoPFsHGJL     banner
# 2108382700.1637753791           4  ZpYIoDJMcFzVoPFsHGJL     banner
# 210838531.1636867288            3  MvfHsxITijuriZxsqZqt        cpm
# 2108385331.1640648523          10  ZpYIoDJMcFzVoPFsHGJL     banner
# 2108385331.1640648523          13  ZpYIoDJMcFzVoPFsHGJL     banner
#
#                                utm_campaign         utm_adcontent  \
# client_id
# 2108382700.1637753791  LEoPHuyFvzoNfnzGgfcd  vCIpmpaGBnIQhyYNkXqp
# 2108382700.1637753791  LEoPHuyFvzoNfnzGgfcd  vCIpmpaGBnIQhyYNkXqp
# 210838531.1636867288   FTjNLDyTrXaWYgZymFkV  xhoenQgDQsgfEPYNPwKO
# 2108385331.1640648523  LEoPHuyFvzoNfnzGgfcd  vCIpmpaGBnIQhyYNkXqp
# 2108385331.1640648523  LEoPHuyFvzoNfnzGgfcd  vCIpmpaGBnIQhyYNkXqp
#
#                                 utm_keyword device_category device_os  \
# client_id
# 2108382700.1637753791  puhZPIYqKXeFPaUviSjo          mobile   Android
# 2108382700.1637753791  puhZPIYqKXeFPaUviSjo          mobile   Android
# 210838531.1636867288   IGUCNvHlhfHpROGclCit          mobile   Android
# 2108385331.1640648523  puhZPIYqKXeFPaUviSjo          mobile   Android
# 2108385331.1640648523  puhZPIYqKXeFPaUviSjo          mobile   Android
#
#                       device_brand device_model device_screen_resolution  \
# client_id
# 2108382700.1637753791       Huawei          NaN                  360x720
# 2108382700.1637753791       Huawei          NaN                  360x720
# 210838531.1636867288       Samsung          NaN                  385x854
# 2108385331.1640648523       Huawei          NaN                  360x720
# 2108385331.1640648523       Huawei          NaN                  360x720
#
#                          device_browser geo_country     geo_city  \
# client_id
# 2108382700.1637753791            Chrome      Russia     Zlatoust
# 2108382700.1637753791            Chrome      Russia     Zlatoust
# 210838531.1636867288   Samsung Internet      Russia       Moscow
# 2108385331.1640648523            Chrome      Russia  Krasnoyarsk
# 2108385331.1640648523            Chrome      Russia  Krasnoyarsk
#
#                        target_action
# client_id
# 2108382700.1637753791              0
# 2108382700.1637753791              0
# 210838531.1636867288               0
# 2108385331.1640648523              0
# 2108385331.1640648523              0

# %%
def outliers_upper_boundary(s: pd.Series) -> float:
    q25 = s.quantile(0.25)
    q75 = s.quantile(0.75)
    iqr = q75 - q25

    return q75 + 1.5 * iqr

# %%
boundary = outliers_upper_boundary(df.hit_number)
df = df.drop(index=df.hit_number.loc[lambda x: x > boundary].index).drop(columns='hit_number')
df.shape
# Out:
# (11896245, 14)

# %%
df.isna().sum()
# Out:
# utm_source                       307
# utm_medium                         0
# utm_campaign                 1545705
# utm_adcontent                2080144
# utm_keyword                  6875486
# device_category                    0
# device_os                    6834051
# device_brand                 2543385
# device_model                11796973
# device_screen_resolution           0
# device_browser                     0
# geo_country                        0
# geo_city                           0
# target_action                      0
# dtype: int64

# %%
for column in df:
    mode = df[column].mode()[0]
    df[column] = df[column].fillna(mode)
df.isna().sum()
# Out:
# utm_source                  0
# utm_medium                  0
# utm_campaign                0
# utm_adcontent               0
# utm_keyword                 0
# device_category             0
# device_os                   0
# device_brand                0
# device_model                0
# device_screen_resolution    0
# device_browser              0
# geo_country                 0
# geo_city                    0
# target_action               0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (379513, 14)

# %% [markdown]
# # Feature Engineering

# %%
x = df.drop(columns='target_action')
y = df.target_action

ohe = OneHotEncoder()
ohe.fit(x)
x = ohe.transform(x)
x.shape
# Out:
# (379513, 9894)

# %% [markdown]
# # Modeling

# %%
models = [
    LogisticRegression(random_state=42, solver='liblinear'),
    RandomForestClassifier(random_state=42, min_samples_leaf=10, max_depth=2000),
    MLPClassifier(random_state=42, early_stopping=True, batch_size=1000)
]

# %%
best_model = None
best_accuracy = 0
best_roc_auc = 0

for model in models:
    name = type(model).__name__
    accuracy = cross_val_score(model, x, y, cv=5)
    model.fit(x, y)
    roc_auc = roc_auc_score(y, model.predict_proba(x)[:, 1])

    print(f'model: {name}, accuracy: {accuracy}, roc_auc: {roc_auc}')
    if roc_auc > best_roc_auc:
        best_model = name
        best_accuracy = accuracy.mean()
        best_roc_auc = roc_auc

f'Best model: {best_model}, accuracy: {best_accuracy}, roc_auc: {best_roc_auc}'
# Out:
# model: LogisticRegression, accuracy: [0.94817069 0.94950134 0.94951451 0.9495402  0.94952702], roc_auc: 0.7977705774288784
# model: RandomForestClassifier, accuracy: [0.94954086 0.94954086 0.94954086 0.94955337 0.94955337], roc_auc: 0.752526924087954
# model: MLPClassifier, accuracy: [0.94690592 0.94954086 0.94954086 0.94955337 0.94955337], roc_auc: 0.7650348383808375
# 'Best model: LogisticRegression, accuracy: 0.9492507517943117, roc_auc: 0.7977705774288784'
